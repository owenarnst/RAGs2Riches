# %%
# !pip install transformers
# !pip install torch
# Out:
# Requirement already satisfied: transformers in /usr/local/lib/python3.10/dist-packages (4.46.2)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from transformers) (3.16.1)
# Requirement already satisfied: huggingface-hub<1.0,>=0.23.2 in /usr/local/lib/python3.10/dist-packages (from transformers) (0.26.2)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.10/dist-packages (from transformers) (1.26.4)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from transformers) (24.2)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from transformers) (6.0.2)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.10/dist-packages (from transformers) (2024.9.11)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from transformers) (2.32.3)
# Requirement already satisfied: safetensors>=0.4.1 in /usr/local/lib/python3.10/dist-packages (from transformers) (0.4.5)
# Requirement already satisfied: tokenizers<0.21,>=0.20 in /usr/local/lib/python3.10/dist-packages (from transformers) (0.20.3)
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.10/dist-packages (from transformers) (4.66.6)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub<1.0,>=0.23.2->transformers) (2024.10.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub<1.0,>=0.23.2->transformers) (4.12.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (3.4.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (2024.8.30)
# Requirement already satisfied: torch in /usr/local/lib/python3.10/dist-packages (2.5.1+cu121)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from torch) (3.16.1)
# Requirement already satisfied: typing-extensions>=4.8.0 in /usr/local/lib/python3.10/dist-packages (from torch) (4.12.2)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch) (3.4.2)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch) (3.1.4)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from torch) (2024.10.0)
# Requirement already satisfied: sympy==1.13.1 in /usr/local/lib/python3.10/dist-packages (from torch) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from sympy==1.13.1->torch) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch) (3.0.2)
# Collecting datasets
#   Downloading datasets-3.1.0-py3-none-any.whl.metadata (20 kB)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from datasets) (3.16.1)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.10/dist-packages (from datasets) (1.26.4)
# Requirement already satisfied: pyarrow>=15.0.0 in /usr/local/lib/python3.10/dist-packages (from datasets) (17.0.0)
# Collecting dill<0.3.9,>=0.3.0 (from datasets)
#   Downloading dill-0.3.8-py3-none-any.whl.metadata (10 kB)
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (from datasets) (2.2.2)
# Requirement already satisfied: requests>=2.32.2 in /usr/local/lib/python3.10/dist-packages (from datasets) (2.32.3)
# Requirement already satisfied: tqdm>=4.66.3 in /usr/local/lib/python3.10/dist-packages (from datasets) (4.66.6)
# Collecting xxhash (from datasets)
#   Downloading xxhash-3.5.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (12 kB)
# Collecting multiprocess<0.70.17 (from datasets)
#   Downloading multiprocess-0.70.16-py310-none-any.whl.metadata (7.2 kB)
# Collecting fsspec<=2024.9.0,>=2023.1.0 (from fsspec[http]<=2024.9.0,>=2023.1.0->datasets)
#   Downloading fsspec-2024.9.0-py3-none-any.whl.metadata (11 kB)
# Requirement already satisfied: aiohttp in /usr/local/lib/python3.10/dist-packages (from datasets) (3.11.2)
# Requirement already satisfied: huggingface-hub>=0.23.0 in /usr/local/lib/python3.10/dist-packages (from datasets) (0.26.2)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from datasets) (24.2)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from datasets) (6.0.2)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (2.4.3)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (1.3.1)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (24.2.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (1.5.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (6.1.0)
# Requirement already satisfied: propcache>=0.2.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (0.2.0)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (1.17.2)
# Requirement already satisfied: async-timeout<6.0,>=4.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (4.0.3)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.23.0->datasets) (4.12.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests>=2.32.2->datasets) (3.4.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests>=2.32.2->datasets) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests>=2.32.2->datasets) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests>=2.32.2->datasets) (2024.8.30)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.10/dist-packages (from pandas->datasets) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas->datasets) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.10/dist-packages (from pandas->datasets) (2024.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.2->pandas->datasets) (1.16.0)
# Downloading datasets-3.1.0-py3-none-any.whl (480 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 480.6/480.6 kB 9.7 MB/s eta 0:00:00
# Downloading dill-0.3.8-py3-none-any.whl (116 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 116.3/116.3 kB 5.8 MB/s eta 0:00:00
# Downloading fsspec-2024.9.0-py3-none-any.whl (179 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 179.3/179.3 kB 12.7 MB/s eta 0:00:00
# Downloading multiprocess-0.70.16-py310-none-any.whl (134 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 134.8/134.8 kB 9.3 MB/s eta 0:00:00
# Downloading xxhash-3.5.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (194 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 194.1/194.1 kB 13.6 MB/s eta 0:00:00
# Installing collected packages: xxhash, fsspec, dill, multiprocess, datasets
#   Attempting uninstall: fsspec
#     Found existing installation: fsspec 2024.10.0
#     Uninstalling fsspec-2024.10.0:
#       Successfully uninstalled fsspec-2024.10.0
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# gcsfs 2024.10.0 requires fsspec==2024.10.0, but you have fsspec 2024.9.0 which is incompatible.
# Successfully installed datasets-3.1.0 dill-0.3.8 fsspec-2024.9.0 multiprocess-0.70.16 xxhash-3.5.0

# %%
import torch
from huggingface_hub import login
from transformers import pipeline
import pandas as pd
import os
from sqlalchemy import create_engine, MetaData, select, Table
from sqlalchemy.orm import Session
import numpy as np
import textwrap

# %%
HF_token = "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"
login(token=HF_token)

# %%
model_id = "meta-llama/Llama-3.2-3B-Instruct"

pipe = pipeline(
  "text-generation",
  model=model_id,
  torch_dtype=torch.bfloat16,
  device_map="auto",
)

# %%
weights = {
    'value': {
        'P/E Ratio': -4,            # Lower P/E indicates undervaluation, but excessive negativity can skew results.
        'P/B Ratio': -3,            # Important for value investors to find companies trading below book value.
        'D/E Ratio': -2,            # Avoid overly leveraged companies; moderate weight.
        'Free Cash Flow': 3,        # Free cash flow is highly desirable, showing financial health and flexibility.
        'Dividend Yield': 3,        # Value stocks often pay dividends; moderate weight here.
        'Net Income': 1,            # Positive net income indicates profitability; important but less critical.
        'Revenue': 1,               # Indicates size and potential; less focus for value investors.
        'Operating Cash Flow': 2,   # Indicates operational efficiency and sustainability.
        'CapEx': -1                 # High CapEx can indicate reinvestment but also increased spending; slight penalty.
    },
    'growth': {
        'Revenue': 5,               # Revenue growth is key for growth investors; highest weight.
        'Net Income': 2,            # Indicates profitability but not the main focus for early-stage growth.
        'Operating Cash Flow': 3,   # Indicates efficient operations; critical for long-term growth sustainability.
        'Free Cash Flow': 2.5,      # Important for growth companies to reinvest in future projects.
        'CapEx': 1.5,               # Growth companies often reinvest heavily; moderate weight.
        'Dividend Yield': -2,       # Growth companies often don’t pay dividends; negative weight.
        'P/E Ratio': 1.5,           # Valuation matters but secondary to growth potential.
        'P/B Ratio': 1,             # Low weight as book value is less relevant for growth.
        'D/E Ratio': -0.5           # Slight penalty for excessive leverage, but growth investors tolerate it.
    },
    'income': {
        'Revenue': 1,               # Provides context for company size and dividend sustainability.
        'Net Income': 2,            # Indicates earnings available to distribute as dividends.
        'Operating Cash Flow': 2.5, # Reflects the ability to generate cash for dividends.
        'Free Cash Flow': 3.5,      # High weight, as free cash flow supports consistent dividend payouts.
        'CapEx': -1.5,              # High CapEx can detract from funds available for dividends.
        'Dividend Yield': 8,        # Most critical metric for income investors.
        'P/E Ratio': 0.5,           # Valuation matters, but not a primary focus.
        'P/B Ratio': 0.5,           # Book value has a minor role for income stocks.
        'D/E Ratio': -1             # Too much debt can threaten dividend sustainability; penalty.
    }
}

# %%
def normalize(values):
    """
    Normalize a list of values using min-max scaling to range [0, 1].
    """
    mean_val = np.mean(values)
    std_dev = np.std(values)
    if std_dev != 0:
        return [(val - mean_val) / std_dev for val in values]
    return [0] * len(values)  # If standard deviation is 0 (i.e., all values are the same)


def calculate_scores(ratios, metrics, investor_type, weights):

    num_periods = len(ratios)

    # Store normalized values in respective lists
    pe_normalized, pb_normalized, de_normalized = [], [], []
    fcf_normalized, div_yield_normalized = [], []
    net_income_normalized, revenue_normalized = [], []
    op_cash_flow_normalized, capex_normalized = [], []

    # Normalize each value by iterating over all periods (quarters)
    for i in range(num_periods):

        metric_row = metrics.iloc[i]
        market_cap = metric_row["Adjusted_Price_Per_Share"] * metric_row["Total_Common_Shares_Outstanding"]

        # Normalizing ratios (P/E, P/B, D/E, Dividend Yield)
        pe_normalized.append(ratios['Price_To_Earnings_Ratio'].iloc[i])
        pb_normalized.append(ratios['Price_To_Book_Ratio'].iloc[i])
        de_normalized.append(ratios['Debt_To_Equity_Ratio'].iloc[i])
        div_yield_normalized.append(ratios['Dividend_Yield'].iloc[i])
        fcf_normalized.append(ratios['Free_Cash_Flow'].iloc[i])

        # Normalizing metrics (Net Income, Revenue, Operating Cash Flow, CapEx) by market cap
        net_income_normalized.append(metric_row['Net_Income'] / market_cap)
        revenue_normalized.append(metric_row['Revenue'] / market_cap)
        op_cash_flow_normalized.append(metric_row['Operating_Cash_Flow'] / market_cap)
        capex_normalized.append(metric_row['Capital_Expenditure'] / market_cap)


    # Now normalize the ratios and metrics using min-max scaling
    pe_normalized = normalize(pe_normalized)
    pb_normalized = normalize(pb_normalized)
    de_normalized = normalize(de_normalized)
    div_yield_normalized = normalize(div_yield_normalized)
    fcf_normalized = normalize(fcf_normalized)

    net_income_normalized = normalize(net_income_normalized)
    revenue_normalized = normalize(revenue_normalized)
    op_cash_flow_normalized = normalize(op_cash_flow_normalized)
    capex_normalized = normalize(capex_normalized)

    scores = []

    for i in range(num_periods-1, -1, -1):  # Reverse iteration (most recent to oldest)

        # For ratios (P/E, P/B, D/E), apply the respective weights
        pe_score = pe_normalized[i] * weights[investor_type]["P/E Ratio"]
        pb_score = pb_normalized[i] * weights[investor_type]["P/B Ratio"]
        de_score = de_normalized[i] * weights[investor_type]["D/E Ratio"]
        div_yield_score = div_yield_normalized[i] * weights[investor_type]["Dividend Yield"]
        fcf_score = fcf_normalized[i] * weights[investor_type]["Free Cash Flow"]

        # For metrics (Net Income, Revenue, Operating Cash Flow, CapEx), apply the respective weights
        net_income_score = net_income_normalized[i] * weights[investor_type]['Net Income']
        revenue_score = revenue_normalized[i] * weights[investor_type]["Revenue"]
        op_cash_flow_score = op_cash_flow_normalized[i] * weights[investor_type]["Operating Cash Flow"]
        capex_score = capex_normalized[i] * weights[investor_type]["CapEx"]

        # Calculate the total score for this period
        total_score = (pe_score + pb_score + de_score + div_yield_score + fcf_score +
                      net_income_score + revenue_score + op_cash_flow_score + capex_score)
        scores.append(total_score)

    # Average the scores across all periods (for normalization later if needed)
    final_score = sum(scores) / len(scores)

    return final_score

# %%
def get_summary(company_id, year, table):
    try:
        summary = session.query(table).filter(
            table.c.CompanyID == int(company_id),
            table.c.Year == int(year)
        ).one_or_none()

        if summary:
            return summary.SummaryText
        else:
            return None  # No summary found for the given CompanyID and Year
    except Exception as e:
        print(f"Error querying summary: {e}")
        return None

# %%
def stringify_metrics(ratios_df, metrics_df, investor_type):
    """
    Convert financial data into a string tailored to the investor type.

    Parameters:
    - ratios_df: DataFrame containing financial ratios (e.g., P/E, P/B, D/E, EPS).
    - metrics_df: DataFrame containing financial metrics (e.g., Revenue, Net Income).
    - investor_type: String specifying the investor type ("value", "growth", or "income").

    Returns:
    - A string summarizing relevant financial data.
    """
    # Initialize an empty list to collect strings for each period
    summary_strings = []

    # Extract company ID
    company_id = ratios_df["CompanyID"].iloc[0]

    # Iterate through each row to process metrics
    for i in range(len(ratios_df)):
        year = ratios_df["Year"].iloc[i]
        quarter = ratios_df["Quarter"].iloc[i]  # Assuming 'Quarter' column exists

        # Fetch metrics
        p_e = round(ratios_df["Price_To_Earnings_Ratio"].iloc[i], 2)
        p_b = round(ratios_df["Price_To_Book_Ratio"].iloc[i], 2)
        d_e = round(ratios_df["Debt_To_Equity_Ratio"].iloc[i], 2)
        div_yield = round(ratios_df["Dividend_Yield"].iloc[i], 2)
        fcf = round(ratios_df["Free_Cash_Flow"].iloc[i], 2)
        basic_eps = round(metrics_df["Basic_EPS"].iloc[i], 2)
        adjusted_price = round(metrics_df["Adjusted_Price_Per_Share"].iloc[i], 2)
        net_income = round(metrics_df["Net_Income"].iloc[i], 2)
        revenue = round(metrics_df["Revenue"].iloc[i], 2)

        # Customize output based on investor type
        if investor_type == "value":
            metrics = (
                f"[P/E: {p_e}, P/B: {p_b}, D/E: {d_e}, EPS: {basic_eps}, "
                f"Adjusted Price: {adjusted_price}, FCF: {fcf},  Revenue: {revenue}]"
            )
        elif investor_type == "growth":
            metrics = (
                f"[Revenue: {revenue}, Net Income: {net_income}, EPS: {basic_eps}, "
                f"Adjusted Price: {adjusted_price}, FCF: {fcf}]"
            )
        elif investor_type == "income":
            metrics = (
                f"[Dividend Yield: {div_yield}%, D/E: {d_e}, "
                f"Adjusted Price: {adjusted_price}, FCF: {fcf}]"
            )
        else:
            metrics = (
                f"[P/E: {p_e}, P/B: {p_b}, D/E: {d_e}, Dividend Yield: {div_yield}%, "
                f"EPS: {basic_eps}, Adjusted Price: {adjusted_price}, FCF: {fcf}, "
                f"Net Income: {net_income}, Revenue: {revenue}]"
            )

        # Append metrics for the current period
        summary_strings.append(
            f"Year: {year}, Quarter: {quarter}, Metrics: {metrics}"
        )

    # Combine all period summaries with new lines for readability
    summary_string = "\n".join(summary_strings)

    return summary_string

# %%
def generate_recommendation(prompt, investor_type):

    investor_messages = {
        "value": """
- Focus on P/E and P/B ratios to assess undervaluation or overvaluation.
- Evaluate D/E for financial stability and FCF for cash generation.
- Look for consistent revenue growth and positive trends in profitability metrics.
- Consider if the company has a competitive advantage or is undervalued relative to peers.
        """,
        "growth": """
- Emphasize revenue and EPS growth as indicators of a company's expansion potential.
- Accept higher P/E or P/B ratios if justified by strong growth metrics.
- Assess if reinvestment strategies (high D/E) are driving sustainable growth.
- Ignore dividends unless they are part of a broader growth strategy.
        """,
        "income": """
- Focus on dividend yield, payout stability, and consistent FCF.
- Evaluate D/E to ensure financial health and capacity to maintain payouts.
- Stable or growing revenue and earnings are critical for income stability.
- P/E and P/B are secondary but should not indicate overvaluation.
        """
    }

    advisor_prompt = f"""
You are a financial advisor creating a comprehensive investment summary tailored to a {investor_type} investor.
Use the following data sources:
1. Historical financial ratios and metrics (P/E, P/B, D/E, FCF, EPS, Revenue, Dividend Yield).
2. Key trends from five years of quarterly data.
3. Summary of Management's Discussion and Analysis (MD&A) from the most recent 10-K filing.

Guidelines:
{investor_messages[investor_type]}

Structure your response as follows:
1. **Investment Overview**: Provide a concise summary of the company's overall financial health and performance trends.
2. **Key Metrics**: Highlight the most relevant metrics based on investor type and explain their significance.
3. **Insights from MD&A**: Integrate qualitative insights from the MD&A to contextualize the financial data.
4. **Final Recommendation**: Conclude with a clear, polished sentence summarizing the investment's suitability for the specified investor type.

Ensure your output is coherent and ends smoothly. Avoid incomplete sentences.
    """

    # Create messages for the model
    messages = [
        {"role": "system", "content": advisor_prompt},
        {"role": "user", "content": f"Here is the data for analysis:\n{prompt}"},
    ]

    # Generate output using the pipeline
    output = pipe(
        messages,
        max_new_tokens=512,
    )

    # Extract the full response
    return output[0]["generated_text"][-1]["content"]

# %%
def custom_wrap_text(text, max_line_length):
  lines = textwrap.wrap(text, width=max_line_length)
  return '\n'.join(lines)

# %%
if __name__=="__main__":

  print("""Which type of investing philosophy aligns with your personal investment goals?

  1. Value Investing:  Value investing focuses on identifying stocks that appear undervalued relative to their intrinsic worth, often assessed through financial metrics
                       such as price-to-earnings or price-to-book ratios. Value investors aim to buy these "bargain" securities and profit when the market eventually recognizes their true value.

  2. Growth Investing: Growth investing focuses on stocks with the potential for above-average market growth, often characterized by high revenue or earnings growth, innovation, or industry disruption.
                       While this style offers the potential for significant rewards, it also carries higher risks, as these companies may be more volatile or unproven.

  3. Income Investing: Income investing prioritizes generating a steady stream of passive income, typically through dividend-paying stocks, bonds, or other income-generating assets.
                       While this approach offers limited potential for explosive gains, it provides stability and predictable returns over time.
        """)

  investor_type = ""
  while investor_type not in ['value', 'growth', 'income']:
    investor_type = input("Enter 'value', 'growth', or 'income': ")


  DATABASE_URL = 'postgresql+psycopg2://u381r20ceebmb7:p2c1b3eb128bb09f92c43d005d55f54c36a4a0e5bd110945652252726dfdb6068@c3gtj1dt5vh48j.cluster-czrs8kj4isg7.us-east-1.rds.amazonaws.com:5432/d77oud95l1v4g6'
  engine = create_engine(DATABASE_URL)

  metrics_df = pd.read_sql(f"SELECT * FROM company_metrics", con=engine)
  ratios_df = pd.read_sql(f"SELECT * FROM company_ratios", con=engine)

  metrics_df = metrics_df[metrics_df["Year"] <= 2021]
  ratios_df = ratios_df[ratios_df["Year"] <= 2021]

  # Create a metadata instance
  metadata = MetaData()

  # Reflect the table from the database
  company_info_table = Table('company_information', metadata, autoload_with=engine)
  company_ten_k_summaries = Table('company_ten_k_summaries', metadata, autoload_with=engine)

  unique_ids = list(metrics_df["CompanyID"].unique())
  scores = dict()

  for id in unique_ids:
    metrics = metrics_df[metrics_df["CompanyID"] == id]
    ratios = ratios_df[ratios_df["CompanyID"] == id]
    score = calculate_scores(ratios, metrics, investor_type, weights)
    scores[id] = score

  session = Session(bind=engine)

  # companies = []
  num_rec = 1
  response = "Recommended Investments for the {investor_type} investor:\n"
  while num_rec < 4:

    top_company = max(scores, key=scores.get)
    scores.pop(top_company)

    query = select(company_info_table).where(company_info_table.c.CompanyID == int(top_company))
    company_info = session.execute(query).fetchone()
    # print(f"{company_info.CompanyName} - {company_info.CompanyID}")
    company_data = stringify_metrics(ratios_df[ratios_df["CompanyID"] == top_company], metrics_df[metrics_df["CompanyID"] == top_company], investor_type)
    company_summary = get_summary(top_company, 2022, company_ten_k_summaries)
    if company_summary is None:
      continue
    company_prompt = f"""Numerical Data:
    {company_data}

    Summary of Management and Discussion:
    {company_summary}
    """

    # print(company_prompt)

    company_response = generate_recommendation(company_prompt, investor_type)
    torch.cuda.empty_cache()

    response += f"""\n{num_rec}. {company_info.CompanyName}, {company_info.Sector} Sector:
{company_response}
          """

    num_rec += 1

  print(custom_wrap(response, 150))

  session.close()
# Out:
# Which type of investing philosophy aligns with your personal investment goals?
#
#   1. Value Investing:  Value investing focuses on identifying stocks that appear undervalued relative to their intrinsic worth, often assessed through financial metrics
#                        such as price-to-earnings or price-to-book ratios. Value investors aim to buy these "bargain" securities and profit when the market eventually recognizes their true value.
#
#   2. Growth Investing: Growth investing focuses on stocks with the potential for above-average market growth, often characterized by high revenue or earnings growth, innovation, or industry disruption.
#                        While this style offers the potential for significant rewards, it also carries higher risks, as these companies may be more volatile or unproven.
#
#   3. Income Investing: Income investing prioritizes generating a steady stream of passive income, typically through dividend-paying stocks, bonds, or other income-generating assets.
#                        While this approach offers limited potential for explosive gains, it provides stability and predictable returns over time.
#
# Enter 'value', 'growth', or 'income': value
# Numerical Data:
#     Year: 2016, Quarter: 4, Metrics: [P/E: 13.44, P/B: 2.71, D/E: 3.86, EPS: 3.54, Adjusted Price: 54.0, FCF: 3156000000,  Revenue: 47011000000]
# Year: 2017, Quarter: 1, Metrics: [P/E: 40.84, P/B: 3.4, D/E: 4.65, EPS: 0.46, Adjusted Price: 61.6, FCF: 4499000000,  Revenue: 9461000000]
# Year: 2017, Quarter: 2, Metrics: [P/E: 44.24, P/B: 3.33, D/E: 4.68, EPS: 0.94, Adjusted Price: 61.61, FCF: 1337000000,  Revenue: 10342000000]
# Year: 2017, Quarter: 3, Metrics: [P/E: 41.67, P/B: 3.79, D/E: 4.58, EPS: 0.48, Adjusted Price: 72.84, FCF: 3550000000,  Revenue: 9160000000]
# Year: 2017, Quarter: 4, Metrics: [P/E: 30.38, P/B: 3.99, D/E: 4.0, EPS: -0.11, Adjusted Price: 76.78, FCF: 4595000000,  Revenue: 38537000000]
# Year: 2018, Quarter: 1, Metrics: [P/E: 38.61, P/B: 5.78, D/E: 4.59, EPS: 0.33, Adjusted Price: 77.43, FCF: 4804000000,  Revenue: 9822000000]
# Year: 2018, Quarter: 2, Metrics: [P/E: 21.29, P/B: 4.94, D/E: 4.11, EPS: 1.36, Adjusted Price: 90.43, FCF: 523000000,  Revenue: 11331000000]
# Year: 2018, Quarter: 3, Metrics: [P/E: 15.72, P/B: 4.66, D/E: 4.29, EPS: 1.79, Adjusted Price: 105.71, FCF: 2438000000,  Revenue: 11413000000]
# Year: 2018, Quarter: 4, Metrics: [P/E: 15.43, P/B: 4.92, D/E: 3.92, EPS: -1.27, Adjusted Price: 134.36, FCF: 3554000000,  Revenue: 45462000000]
# Year: 2019, Quarter: 1, Metrics: [P/E: 12.94, P/B: 4.65, D/E: 4.58, EPS: 2.78, Adjusted Price: 126.24, FCF: 5282000000,  Revenue: 12859000000]
# Year: 2019, Quarter: 2, Metrics: [P/E: 13.11, P/B: 4.4, D/E: 4.09, EPS: 2.86, Adjusted Price: 116.8, FCF: 843000000,  Revenue: 14011000000]
# Year: 2019, Quarter: 3, Metrics: [P/E: 13.28, P/B: 4.59, D/E: 4.32, EPS: 2.92, Adjusted Price: 132.09, FCF: 3230000000,  Revenue: 747000000]
# Year: 2019, Quarter: 4, Metrics: [P/E: 12.72, P/B: 4.17, D/E: 4.2, EPS: -10.39, Adjusted Price: 110.79, FCF: 3755000000,  Revenue: 2900000000]
# Year: 2020, Quarter: 1, Metrics: [P/E: 14.99, P/B: 5.08, D/E: 4.36, EPS: 3.29, Adjusted Price: 118.88, FCF: 5856000000,  Revenue: 742000000]
# Year: 2020, Quarter: 2, Metrics: [P/E: 13.89, P/B: 4.02, D/E: 4.33, EPS: 2.85, Adjusted Price: 120.3, FCF: 825000000,  Revenue: 761000000]
# Year: 2020, Quarter: 3, Metrics: [P/E: 20.83, P/B: 4.53, D/E: 4.56, EPS: 2.69, Adjusted Price: 112.33, FCF: 2049000000,  Revenue: 784000000]
# Year: 2020, Quarter: 4, Metrics: [P/E: 33.62, P/B: 4.95, D/E: 4.12, EPS: -10.85, Adjusted Price: 132.37, FCF: 3569000000,  Revenue: 3045000000]
# Year: 2021, Quarter: 1, Metrics: [P/E: 41.28, P/B: 5.94, D/E: 4.09, EPS: 2.0, Adjusted Price: 104.74, FCF: 5349000000,  Revenue: 9914000000]
# Year: 2021, Quarter: 2, Metrics: [P/E: 44.18, P/B: 7.07, D/E: 3.86, EPS: 0.84, Adjusted Price: 115.19, FCF: 1676000000,  Revenue: 687000000]
# Year: 2021, Quarter: 3, Metrics: [P/E: 30.69, P/B: 6.63, D/E: 3.84, EPS: 1.23, Adjusted Price: 136.83, FCF: 3627000000,  Revenue: 653000000]
# Year: 2021, Quarter: 4, Metrics: [P/E: 22.49, P/B: 5.86, D/E: 3.84, EPS: -5.51, Adjusted Price: 168.01, FCF: 5113000000,  Revenue: 2726000000]
#
#     Summary of Management and Discussion:
#     The Management's Discussion and Analysis (MD&A) provides an overview of Caterpillar's financial
# performance for 2021, highlighting key increases in sales and revenues, operating profit, and
# certain expenses, while also discussing the impact of the COVID-19 pandemic, supply chain
# disruptions, and changes in dealer inventories. The report begins by stating that sales and revenues
# Caterpillar's performance in the fourth quarter and year 2021, as well as 2020, can be summarized as
# follows:  - The company's total sales increased by 23% in the fourth quarter of 2021 compared to the
# same period in 2020, reaching $13.798 billion, while total sales for the full year The Construction
# Industries segment reported higher sales volume and favorable price realization, contributing to a
# 25% increase in profit to $788 million, compared to $630 million in the same period last year. In
# contrast, Resource Industries experienced lower sales volume, leading to a 12% increase in profit to
# $305 million, while Energy & Transportation's profit decreased by Caterpillar's financial situation
# as of December 31, 2021, and the terms of its credit facility, provides context for the company's
# financial obligations and potential risks. The company has two main credit facilities: a three-year
# facility of $2.73 billion (with $715 million available to Machinery, Energy & Transportation
# Financial Products) expiring The information presented in this document relates to Caterpillar's
# financial position and obligations as of December 31, 2021 and 2020, including warranty costs,
# postretirement benefits, insurance loss reserves, and income taxes. The document highlights the
# estimated reserves for product liability and insurance loss, which total $1.2 billion at both
# December 31 The company's objective for managing foreign currency risk is to minimize earnings
# volatility resulting from conversion and remeasurement of net foreign currency balance sheet
# positions and future transactions denominated in foreign currencies. A 10% change in the U.S.
# dollar's value relative to other currencies would not have a material effect on the company's
# consolidated financial position, results of operations This financial report presents a consolidated
# statement of cash flow for the years ended December 31, along with various eliminations and
# adjustments, indicating that the cash flow data may not accurately reflect the standalone financial
# performance of ME&T and Financial Products. However, after accounting for the eliminations and
# adjustments, the consolidated cash flow data shows:  - A net increase in cash
#
# Numerical Data:
#     Year: 2016, Quarter: 4, Metrics: [P/E: 2.6, P/B: 0.77, D/E: 1.57, EPS: 4.58, Adjusted Price: 18.65, FCF: 12185000000,  Revenue: 482130000000]
# Year: 2017, Quarter: 1, Metrics: [P/E: 4.39, P/B: 0.74, D/E: 1.47, EPS: 0.98, Adjusted Price: 18.94, FCF: 20911000000,  Revenue: 115904000000]
# Year: 2017, Quarter: 2, Metrics: [P/E: 4.96, P/B: 0.87, D/E: 1.62, EPS: 1.21, Adjusted Price: 20.82, FCF: 3395000000,  Revenue: 120854000000]
# Year: 2017, Quarter: 3, Metrics: [P/E: 5.63, P/B: 0.89, D/E: 1.55, EPS: 0.98, Adjusted Price: 20.11, FCF: 6937000000,  Revenue: 118179000000]
# Year: 2017, Quarter: 4, Metrics: [P/E: 6.82, P/B: 0.97, D/E: 1.65, EPS: 4.4, Adjusted Price: 19.31, FCF: 10152000000,  Revenue: 485873000000]
# Year: 2018, Quarter: 1, Metrics: [P/E: 9.61, P/B: 1.17, D/E: 1.53, EPS: 1.0, Adjusted Price: 21.91, FCF: 18286000000,  Revenue: 117542000000]
# Year: 2018, Quarter: 2, Metrics: [P/E: 8.77, P/B: 0.99, D/E: 1.62, EPS: 0.96, Adjusted Price: 23.46, FCF: 3343000000,  Revenue: 123355000000]
# Year: 2018, Quarter: 3, Metrics: [P/E: 15.23, P/B: 1.07, D/E: 1.79, EPS: 0.59, Adjusted Price: 25.77, FCF: 6813000000,  Revenue: 123179000000]
# Year: 2018, Quarter: 4, Metrics: [P/E: 17.31, P/B: 1.11, D/E: 1.85, EPS: 3.29, Adjusted Price: 31.63, FCF: 10294000000,  Revenue: 500343000000]
# Year: 2019, Quarter: 1, Metrics: [P/E: 12.88, P/B: 1.07, D/E: 1.75, EPS: 0.72, Adjusted Price: 26.4, FCF: 17409000000,  Revenue: 122690000000]
# Year: 2019, Quarter: 2, Metrics: [P/E: 10.91, P/B: 1.21, D/E: 2.13, EPS: -0.29, Adjusted Price: 26.8, FCF: 1358000000,  Revenue: 128028000000]
# Year: 2019, Quarter: 3, Metrics: [P/E: 17.84, P/B: 1.26, D/E: 2.04, EPS: 0.58, Adjusted Price: 30.3, FCF: 6314000000,  Revenue: 124894000000]
# Year: 2019, Quarter: 4, Metrics: [P/E: 14.65, P/B: 1.32, D/E: 2.06, EPS: 2.26, Adjusted Price: 29.11, FCF: 6774000000,  Revenue: 514405000000]
# Year: 2020, Quarter: 1, Metrics: [P/E: 6.84, P/B: 1.25, D/E: 1.9, EPS: 1.34, Adjusted Price: 31.41, FCF: 14550000000,  Revenue: 123925000000]
# Year: 2020, Quarter: 2, Metrics: [P/E: 7.19, P/B: 1.45, D/E: 2.14, EPS: -1.27, Adjusted Price: 33.89, FCF: 5265000000,  Revenue: 130377000000]
# Year: 2020, Quarter: 3, Metrics: [P/E: 4.6, P/B: 1.42, D/E: 1.92, EPS: 1.15, Adjusted Price: 36.18, FCF: 15387000000,  Revenue: 127991000000]
# Year: 2020, Quarter: 4, Metrics: [P/E: 4.61, P/B: 1.42, D/E: 1.87, EPS: 5.19, Adjusted Price: 35.48, FCF: 16442000000,  Revenue: 523964000000]
# Year: 2021, Quarter: 1, Metrics: [P/E: 8.08, P/B: 1.44, D/E: 1.88, EPS: 1.41, Adjusted Price: 37.84, FCF: 25810000000,  Revenue: 134622000000]
# Year: 2021, Quarter: 2, Metrics: [P/E: 8.79, P/B: 1.48, D/E: 1.8, EPS: 2.27, Adjusted Price: 40.46, FCF: 644000000,  Revenue: 137742000000]
# Year: 2021, Quarter: 3, Metrics: [P/E: 10.53, P/B: 1.46, D/E: 1.74, EPS: 1.8, Adjusted Price: 43.56, FCF: 7404000000,  Revenue: 134708000000]
# Year: 2021, Quarter: 4, Metrics: [P/E: 13.2, P/B: 1.47, D/E: 1.7, EPS: 4.75, Adjusted Price: 44.27, FCF: 7703000000,  Revenue: 559151000000]
#
#     Summary of Management and Discussion:
#     This report provides an overview of Walmart's financial condition and results of operations for the
# fiscal years ended January 31, 2022, 2021, and 2020, as requested in Item 7 of the management's
# discussion and analysis of financial condition and results of operations.   Walmart's operating
# results, including segment operating income, comparable store and club sales, and eCommerce sales,
# are discussed in the report to provide a better understanding of the company's performance and how
# it affects its overall financial position and results of operations. The company measures its
# segment performance using operating income, including corporate overhead allocations, as well as The
# company reports a decrease in capital expenditures of $0.4 billion, but notes that its definition of
# free cash flow is limited, as it does not deduct payments for debt service, other contractual
# obligations, or business acquisitions. The company provides a reconciliation of its non-GAAP free
# cash flow to its GAAP cash flow from operating activities, and reports the following amounts for
# free cash flow: $11.075 billion for fiscal year 2022, $25.810 billion for fiscal year 2021, and
# $14.550 billion for fiscal year 2020. The company also reports its consolidated results of
# operations, The company's gross profit rate decreased 68 basis points in fiscal 2022 and increased
# 65 basis points in fiscal 2021 compared to the previous fiscal year. This was primarily due to
# increased fuel sales with lower margins, cost inflation, and higher supply chain costs in fiscal
# 2022, and lower fuel and tobacco sales, as well as improvement in inventory losses in fiscal 2021.
# Membership and other income increased 13.1% in fiscal 2022 and 6.8% in fiscal 2021. Operating
# expenses as a percentage of segment net sales decreased 82 basis points in fiscal 202 The company
# discusses several contingent liabilities, including securities class actions and derivative
# litigation, Asda Equal Value Claims, Money Transfer Agent Services, and Foreign Direct Investment
# matters, as well as an environmental matter with the State of California. It also describes its
# critical accounting estimates, including inventory valuation using the lower of cost or market
# method, impairment of long-lived assets, valuation of business combinations, and income tax
# provisions. The company notes that its estimates and judgments may change over time and that actual
# results may differ from its estimates, and that it continually reviews its accounting policies and
# estimates to ensure transparency and clarity in its financial reporting.
#
# Numerical Data:
#     Year: 2016, Quarter: 4, Metrics: [P/E: 5.45, P/B: 0.49, D/E: 7.13, EPS: 1.38, Adjusted Price: 13.91, FCF: 26662000000,  Revenue: 82507000000]
# Year: 2017, Quarter: 1, Metrics: [P/E: 11.74, P/B: 0.7, D/E: 7.2, EPS: 0.21, Adjusted Price: 11.22, FCF: 18306000000,  Revenue: 226000000]
# Year: 2017, Quarter: 2, Metrics: [P/E: 11.03, P/B: 0.74, D/E: 7.38, EPS: 0.38, Adjusted Price: 11.05, FCF: 12846000000,  Revenue: 267000000]
# Year: 2017, Quarter: 3, Metrics: [P/E: 10.73, P/B: 0.75, D/E: 7.32, EPS: 0.43, Adjusted Price: 13.09, FCF: 3020000000,  Revenue: 21635000000]
# Year: 2017, Quarter: 4, Metrics: [P/E: 10.86, P/B: 0.83, D/E: 7.38, EPS: 1.58, Adjusted Price: 18.55, FCF: 17451000000,  Revenue: 83701000000]
# Year: 2018, Quarter: 1, Metrics: [P/E: 15.44, P/B: 0.97, D/E: 7.54, EPS: 0.43, Adjusted Price: 19.86, FCF: 10403000000,  Revenue: 22248000000]
# Year: 2018, Quarter: 2, Metrics: [P/E: 14.1, P/B: 0.98, D/E: 7.75, EPS: 0.49, Adjusted Price: 20.49, FCF: 40354000000,  Revenue: 101000000]
# Year: 2018, Quarter: 3, Metrics: [P/E: 12.36, P/B: 0.92, D/E: 7.67, EPS: 0.5, Adjusted Price: 21.51, FCF: 33836000000,  Revenue: 125000000]
# Year: 2018, Quarter: 4, Metrics: [P/E: 11.94, P/B: 0.96, D/E: 7.92, EPS: 1.63, Adjusted Price: 25.16, FCF: 53442000000,  Revenue: 255000000]
# Year: 2019, Quarter: 1, Metrics: [P/E: 8.1, P/B: 0.78, D/E: 7.87, EPS: 0.62, Adjusted Price: 25.66, FCF: 39520000000,  Revenue: 23125000000]
# Year: 2019, Quarter: 2, Metrics: [P/E: 8.82, P/B: 0.86, D/E: 7.9, EPS: 0.63, Adjusted Price: 24.22, FCF: 15101000000,  Revenue: 22609000000]
# Year: 2019, Quarter: 3, Metrics: [P/E: 8.96, P/B: 0.91, D/E: 7.83, EPS: 0.67, Adjusted Price: 25.44, FCF: 8376000000,  Revenue: 22777000000]
# Year: 2019, Quarter: 4, Metrics: [P/E: 9.44, P/B: 0.87, D/E: 8.04, EPS: 2.64, Adjusted Price: 21.4, FCF: 2674000000,  Revenue: 91247000000]
# Year: 2020, Quarter: 1, Metrics: [P/E: 11.37, P/B: 1.14, D/E: 8.19, EPS: 0.71, Adjusted Price: 24.08, FCF: 61777000000,  Revenue: 23004000000]
# Year: 2020, Quarter: 2, Metrics: [P/E: 7.78, P/B: 0.62, D/E: 8.89, EPS: 0.74, Adjusted Price: 25.45, FCF: 19043000000,  Revenue: 23084000000]
# Year: 2020, Quarter: 3, Metrics: [P/E: 10.28, P/B: 0.7, D/E: 9.32, EPS: 0.56, Adjusted Price: 25.76, FCF: 16037000000,  Revenue: 22807000000]
# Year: 2020, Quarter: 4, Metrics: [P/E: 10.75, P/B: 0.7, D/E: 9.19, EPS: 2.75, Adjusted Price: 31.27, FCF: 16601000000,  Revenue: 91244000000]
# Year: 2021, Quarter: 1, Metrics: [P/E: 14.78, P/B: 0.88, D/E: 9.33, EPS: 0.4, Adjusted Price: 18.98, FCF: 37993000000,  Revenue: 22767000000]
# Year: 2021, Quarter: 2, Metrics: [P/E: 15.15, P/B: 1.11, D/E: 9.84, EPS: 0.38, Adjusted Price: 21.37, FCF: 52328000000,  Revenue: 22326000000]
# Year: 2021, Quarter: 3, Metrics: [P/E: 12.69, P/B: 1.16, D/E: 9.93, EPS: 0.51, Adjusted Price: 21.83, FCF: 61639000000,  Revenue: 20336000000]
# Year: 2021, Quarter: 4, Metrics: [P/E: 11.75, P/B: 1.19, D/E: 10.32, EPS: 1.87, Adjusted Price: 27.64, FCF: 51844000000,  Revenue: 85528000000]
#
#     Summary of Management and Discussion:
#     The information provided in the MD&A and Note 23 sections of Bank of America's financial statements
# discusses the The Federal Reserve and FDIC have determined that Bank of America's plan is not
# credible, potentially leading to The document discusses the potential risks and factors that could
# impact Bank of America's operations, financial condition, and Bank of America Corporation faces
# various risks that could impact its financial condition, operations, and results of operations, The
# Bank of America faces numerous risks that could impact its compliance costs, business operations,
# and financial condition, Bank of America faces heightened levels of operational, reputational, and
# compliance risk due to uncertain economic conditions, The Bank of America document discusses various
# risks and challenges facing the company, including regulatory and public expectations regarding
# consumer Bank of America Corporation's Financial Overview as of December 31, 2021, provides an
# overview of The Corporation is assessing and planning to leverage relevant contractual and statutory
# solutions, including state legislation and future federal legislation Bank of America's financial
# data for 2021, 2020, and 2019, as The table provides Bank of America's financial data for Consumer
# Banking, including net interest income, noninterest income Bank of America's Deposits segment
# reported a net interest income of $14.4 billion, a  Bank of America's financial performance for the
# year 2021, as reported in the document, highlights increases The framework at Bank of America
# outlines a comprehensive approach to risk management, governance, and regulatory compliance. The
# Bank of America Corporation's capital ratios and regulatory compliance as of December 31, 2021 and
# BofASE, a French investment firm regulated by the Autorité de Contrôle Prudentiel et de The Bank of
# America Corporation's liquidity, credit risk management, and credit portfolio quality are discussed
# in the report The Net charge-off ratios are calculated as net charge-offs divided by average
# outstanding loans and leases excluding loans accounted Bank of America's nonperforming loans and
# leases increased from $2,725 to $2,989 Bank of America's commercial real estate portfolio, managed
# primarily in Global Banking, reported a total outstanding commercial real Bank of America's
# financial report for December 31, 2021, highlights several key areas, including The document
# discusses the risk management strategies employed by Bank of America, focusing on market risk, which
# encompasses various The Bank of America document discusses its strategies and risks management
# approaches, including managing interest rate risk, compliance and The allowance for credit losses,
# which includes the allowance for loan and lease losses and the reserve for unfunded
#
# Numerical Data:
#     Year: 2016, Quarter: 4, Metrics: [P/E: 10.72, P/B: 5.47, D/E: 0.58, EPS: 2.86, Adjusted Price: 42.96, FCF: 2608000000,  Revenue: 13000000000]
# Year: 2017, Quarter: 1, Metrics: [P/E: 16.59, P/B: 5.63, D/E: 0.57, EPS: 0.65, Adjusted Price: 45.34, FCF: -309000000,  Revenue: 3008000000]
# Year: 2017, Quarter: 2, Metrics: [P/E: 16.82, P/B: 6.12, D/E: 0.5, EPS: 0.77, Adjusted Price: 49.79, FCF: 668000000,  Revenue: 3273000000]
# Year: 2017, Quarter: 3, Metrics: [P/E: 15.07, P/B: 5.82, D/E: 0.54, EPS: 0.95, Adjusted Price: 56.08, FCF: 1434000000,  Revenue: 3675000000]
# Year: 2017, Quarter: 4, Metrics: [P/E: 16.34, P/B: 6.61, D/E: 0.54, EPS: 3.54, Adjusted Price: 58.74, FCF: 2970000000,  Revenue: 13370000000]
# Year: 2018, Quarter: 1, Metrics: [P/E: 25.89, P/B: 8.27, D/E: 0.71, EPS: 0.99, Adjusted Price: 65.26, FCF: 4668000000,  Revenue: 3402000000]
# Year: 2018, Quarter: 2, Metrics: [P/E: 23.18, P/B: 7.97, D/E: 0.65, EPS: 1.05, Adjusted Price: 62.71, FCF: 923000000,  Revenue: 3693000000]
# Year: 2018, Quarter: 3, Metrics: [P/E: 22.45, P/B: 8.46, D/E: 0.74, EPS: 1.29, Adjusted Price: 73.52, FCF: 2500000000,  Revenue: 4116000000]
# Year: 2018, Quarter: 4, Metrics: [P/E: 20.38, P/B: 8.3, D/E: 0.77, EPS: 0.35, Adjusted Price: 86.21, FCF: 4236000000,  Revenue: 3750000000]
# Year: 2019, Quarter: 1, Metrics: [P/E: 14.01, P/B: 8.63, D/E: 0.91, EPS: 1.38, Adjusted Price: 86.24, FCF: 6058000000,  Revenue: 3789000000]
# Year: 2019, Quarter: 2, Metrics: [P/E: 16.1, P/B: 9.97, D/E: 1.05, EPS: 1.43, Adjusted Price: 92.06, FCF: 856000000,  Revenue: 4017000000]
# Year: 2019, Quarter: 3, Metrics: [P/E: 17.69, P/B: 10.88, D/E: 1.05, EPS: 1.61, Adjusted Price: 90.09, FCF: 2368000000,  Revenue: 4261000000]
# Year: 2019, Quarter: 4, Metrics: [P/E: 20.41, P/B: 11.62, D/E: 1.0, EPS: 5.71, Adjusted Price: 80.01, FCF: 4211000000,  Revenue: 15784000000]
# Year: 2020, Quarter: 1, Metrics: [P/E: 20.95, P/B: 11.73, D/E: 1.02, EPS: 1.29, Adjusted Price: 90.48, FCF: 5802000000,  Revenue: 3594000000]
# Year: 2020, Quarter: 2, Metrics: [P/E: 16.56, P/B: 10.55, D/E: 1.23, EPS: 1.38, Adjusted Price: 98.54, FCF: 690000000,  Revenue: 3668000000]
# Year: 2020, Quarter: 3, Metrics: [P/E: 20.74, P/B: 13.45, D/E: 1.28, EPS: 1.51, Adjusted Price: 111.63, FCF: 2280000000,  Revenue: 3771000000]
# Year: 2020, Quarter: 4, Metrics: [P/E: 23.67, P/B: 14.0, D/E: 1.19, EPS: 5.33, Adjusted Price: 111.66, FCF: 3577000000,  Revenue: 14383000000]
# Year: 2021, Quarter: 1, Metrics: [P/E: 24.31, P/B: 14.75, D/E: 1.11, EPS: 1.25, Adjusted Price: 87.61, FCF: 358000000,  Revenue: 3329000000]
# Year: 2021, Quarter: 2, Metrics: [P/E: 25.47, P/B: 15.46, D/E: 0.93, EPS: 1.5, Adjusted Price: 112.22, FCF: 1542000000,  Revenue: 3239000000]
# Year: 2021, Quarter: 3, Metrics: [P/E: 23.99, P/B: 14.43, D/E: 0.85, EPS: 1.47, Adjusted Price: 127.09, FCF: 3277000000,  Revenue: 3817000000]
# Year: 2021, Quarter: 4, Metrics: [P/E: 22.18, P/B: 13.31, D/E: 0.92, EPS: 6.05, Adjusted Price: 147.1, FCF: -262000000,  Revenue: 14461000000]
#
#     Summary of Management and Discussion:
#     The document discusses Texas Instruments' (TI) strategy and financial performance for 2021, as
# outlined in their Management's Discussion and Analysis (MD&A) section. The company's focus is on
# designing and selling semiconductors to electronics designers and manufacturers worldwide, with a
# goal of maximizing free cash flow per share. Their strategy is built on four sustainable competitive
# advantages: a strong foundation of manufacturing and technology, a broad portfolio of analog and
# embedded processing products, a reach of market channels, and diversity and longevity of products,
# markets, and customer positions.  In 2021, TI reported revenue of $18.34 billion, an increase of 27%
# from 2020, driven mainly by higher revenue from Analog and Embedded Processing products. Gross
# margin was 67.5%, reflecting the quality of their product portfolio and manufacturing efficiency.
# The company generated $8.76 billion in cash from operations and $6.29 billion in free cash flow,
# with 34.3% of revenue going towards free cash flow. TI returned $4.41 billion to shareholders
# through dividends and stock repurchases, with dividends accounting for 62% of free cash flow.  The
# MD&A also discusses TI's liquidity and capital resources, including their primary source of
# liquidity, cash flow from operations, and access to debt markets. The company had $9.74 billion in
# total cash and cash equivalents plus short-term investments at the end of 2021, with a variable rate
# revolving credit facility that was undrawn. TI's capital expenditures were $2.46 billion, primarily
# for semiconductor manufacturing equipment and facilities, and their financing activities involved
# debt issuance and share repurchases.  The document also highlights the company's accounting policies
# and estimates, including the use of free cash flow and annual operating tax rate as non-GAAP
# financial measures. TI's accounting policies require judgment and estimates, such as the calculation
# of tax provisions and the recoverability of deferred tax assets. The company's valuation allowances
# for inventory are determined quarterly based on historical disposals and statistical analysis.
# Overall, TI's strategy and financial performance for 2021 demonstrate the company's focus on
# designing and selling semiconductors, its commitment to maximizing free cash flow per share, and its
# efforts to strengthen its competitive advantages through investments in manufacturing and
# technology.
#
# Numerical Data:
#     Year: 2020, Quarter: 2, Metrics: [P/E: 16.08, P/B: 1.82, D/E: 1.17, EPS: 3.56, Adjusted Price: 108.83, FCF: 2202000000,  Revenue: 1916000000]
# Year: 2020, Quarter: 3, Metrics: [P/E: -526.85, P/B: 2.2, D/E: 1.3, EPS: 0.98, Adjusted Price: 136.88, FCF: 2656000000,  Revenue: 2223000000]
# Year: 2020, Quarter: 4, Metrics: [P/E: -101.1, P/B: 2.45, D/E: 1.28, EPS: 6.68, Adjusted Price: 128.53, FCF: 3594000000,  Revenue: 9028000000]
# Year: 2021, Quarter: 1, Metrics: [P/E: -71.0, P/B: 3.38, D/E: 1.28, EPS: 1.17, Adjusted Price: 143.5, FCF: -685000000,  Revenue: 2783000000]
# Year: 2021, Quarter: 2, Metrics: [P/E: -87.89, P/B: 3.7, D/E: 1.23, EPS: 0.25, Adjusted Price: 95.85, FCF: -62000000,  Revenue: 1835000000]
# Year: 2021, Quarter: 3, Metrics: [P/E: 17464.58, P/B: 3.45, D/E: 1.22, EPS: -2.61, Adjusted Price: 110.64, FCF: 466000000,  Revenue: 544000000]
# Year: 2021, Quarter: 4, Metrics: [P/E: 16775.01, P/B: 3.25, D/E: 1.19, EPS: -1.58, Adjusted Price: 120.3, FCF: 1988000000,  Revenue: 6123000000]
#
#     Summary of Management and Discussion:
#     The company's financial performance and condition for the year 2022 are compared to 2021, with
# notable increases in revenue and net income. Revenues rose 23% to $82.7 billion, with service
# revenues increasing 20% to $74.2 billion and product revenues rising 51% to $8.5 billion. In
# contrast, costs and expenses increased 19% to $75.9 billion, with cost of services rising 19% to
# $48.9 billion The Company reports total segment revenues of $83,745 million for 2022 and $67,418
# million for 2021, representing a 24% increase. The total segment operating income was $12,121
# million for 2022 and $7,766 million for 2021, representing a 56% increase. The segment revenue and
# operating results are broken down by two main segments: Disney Media and Entertainment Distribution
# and Disney Parks, Experiences and Products. Disney Media and Entertainment Distribution The average
# monthly revenue per paid subscriber for the Hulu Live TV + SVOD service increased from $81.35 to
# $87.62, driven by an increase in retail pricing and higher per-subscriber advertising revenue,
# partially offset by a higher mix of subscribers to multi-product offerings. Disney's operating
# expenses were $17,440 million, a 32% increase from $13,234 million, driven by higher programming and
# production costs at Disney+, Hulu, and ESPN+, as well as other operating expenses The Company's
# fiscal 2022 financial information, including its ending balances of production and programming
# assets and liabilities, as well as its capital expenditures and cash flows, provide insight into its
# financial performance and outlook. The Company expects its fiscal 2023 spend on produced and
# licensed content to be in the low $30 billion range, and it has contractual commitments to acquire
# sports and broadcast programming. The Company has various commitments and guarantees, such as long-
# term leases and executory contracts, that are disclosed in the The company performed a quantitative
# assessment of goodwill for impairment in fiscal 2022, bypassing the qualitative assessment, and
# determined that carrying amounts of reporting units exceeded fair values in that year, particularly
# in Russia, although no specific numbers were provided for the fiscal year 2022 impairment charges
# which were $0.2 billion, and compared fair values of reporting units to their carrying amounts,
# recognizing impairment charges if the carrying amount exceeded fair value. The company uses a
# present value technique (discounted cash flows)
#
# Numerical Data:
#     Year: 2016, Quarter: 4, Metrics: [P/E: 7.74, P/B: 3.16, D/E: 1.54, EPS: 9.15, Adjusted Price: 124.56, FCF: 6743000000,  Revenue: 21662000000]
# Year: 2017, Quarter: 1, Metrics: [P/E: 11.16, P/B: 2.85, D/E: 1.6, EPS: 2.52, Adjusted Price: 115.86, FCF: 9616000000,  Revenue: 5527000000]
# Year: 2017, Quarter: 2, Metrics: [P/E: 12.26, P/B: 3.13, D/E: 1.54, EPS: 2.49, Adjusted Price: 118.35, FCF: 2217000000,  Revenue: 5688000000]
# Year: 2017, Quarter: 3, Metrics: [P/E: 12.45, P/B: 3.17, D/E: 1.51, EPS: 2.7, Adjusted Price: 130.49, FCF: 4358000000,  Revenue: 5811000000]
# Year: 2017, Quarter: 4, Metrics: [P/E: 13.47, P/B: 3.38, D/E: 1.49, EPS: 10.32, Adjusted Price: 115.16, FCF: 7654000000,  Revenue: 22991000000]
# Year: 2018, Quarter: 1, Metrics: [P/E: 16.52, P/B: 4.03, D/E: 2.17, EPS: 2.81, Adjusted Price: 130.11, FCF: 10513000000,  Revenue: 5464000000]
# Year: 2018, Quarter: 2, Metrics: [P/E: 15.48, P/B: 5.93, D/E: 3.56, EPS: 2.93, Adjusted Price: 137.57, FCF: 2572000000,  Revenue: 5810000000]
# Year: 2018, Quarter: 3, Metrics: [P/E: 15.92, P/B: 6.6, D/E: 3.54, EPS: 2.78, Adjusted Price: 149.93, FCF: 4487000000,  Revenue: 5773000000]
# Year: 2018, Quarter: 4, Metrics: [P/E: 17.81, P/B: 7.65, D/E: 3.69, EPS: 2.69, Adjusted Price: 140.78, FCF: 7589000000,  Revenue: 22849000000]
# Year: 2019, Quarter: 1, Metrics: [P/E: 12.85, P/B: 9.37, D/E: 4.31, EPS: 3.27, Adjusted Price: 139.03, FCF: 10558000000,  Revenue: 5554000000]
# Year: 2019, Quarter: 2, Metrics: [P/E: 12.71, P/B: 9.04, D/E: 4.91, EPS: 3.48, Adjusted Price: 151.68, FCF: 1729000000,  Revenue: 6059000000]
# Year: 2019, Quarter: 3, Metrics: [P/E: 12.32, P/B: 8.7, D/E: 4.5, EPS: 2.88, Adjusted Price: 171.47, FCF: 2999000000,  Revenue: 5904000000]
# Year: 2019, Quarter: 4, Metrics: [P/E: 12.62, P/B: 9.0, D/E: 4.45, EPS: 12.62, Adjusted Price: 162.14, FCF: 6206000000,  Revenue: 23747000000]
# Year: 2020, Quarter: 1, Metrics: [P/E: 15.97, P/B: 12.65, D/E: 5.17, EPS: 3.2, Adjusted Price: 159.46, FCF: 8532000000,  Revenue: 5557000000]
# Year: 2020, Quarter: 2, Metrics: [P/E: 13.64, P/B: 10.87, D/E: 5.5, EPS: 3.59, Adjusted Price: 156.0, FCF: 1992000000,  Revenue: 5871000000]
# Year: 2020, Quarter: 3, Metrics: [P/E: 16.65, P/B: 11.29, D/E: 5.1, EPS: 3.29, Adjusted Price: 165.01, FCF: 4676000000,  Revenue: 5737000000]
# Year: 2020, Quarter: 4, Metrics: [P/E: 17.86, P/B: 11.86, D/E: 4.9, EPS: 12.96, Adjusted Price: 206.92, FCF: 7909000000,  Revenue: 23362000000]
# Year: 2021, Quarter: 1, Metrics: [P/E: 16.35, P/B: 12.75, D/E: 5.69, EPS: 3.09, Adjusted Price: 175.26, FCF: 9889000000,  Revenue: 6161000000]
# Year: 2021, Quarter: 2, Metrics: [P/E: 18.18, P/B: 13.63, D/E: 5.7, EPS: 3.07, Adjusted Price: 205.26, FCF: 1938000000,  Revenue: 6206000000]
# Year: 2021, Quarter: 3, Metrics: [P/E: 22.03, P/B: 15.06, D/E: 6.25, EPS: 3.43, Adjusted Price: 222.67, FCF: 3684000000,  Revenue: 6423000000]
# Year: 2021, Quarter: 4, Metrics: [P/E: 19.6, P/B: 13.18, D/E: 6.91, EPS: 12.4, Adjusted Price: 202.79, FCF: 5860000000,  Revenue: 25424000000]
#
#     Summary of Management and Discussion:
#     Amgen markets a variety of biologic and small molecule products for the treatment of various
# diseases, including rheumatoid arthritis, psoriasis, osteoporosis Amgen faces challenges in
# maintaining its sales and profitability due to the competitive landscape of the biopharmaceutical
# industry, with increasing competition from biosimilars The FDA has authorized the approval of
# biosimilars via a separate, abbreviated pathway, allowing sponsors to rely on nonclinical-trial and
# clinical-trial Amgen has developed and is developing several product candidates for various
# indications, including LUMAKRAS/LUMYKRAS for NSCLC with KR In 2021, Amgen implemented various
# measures to ensure the safety of its employees, including remote work options, occupancy limits, and
# COVID-19 testing The COVID-19 pandemic has had a significant impact on the company's business,
# operations, and financial condition, as described in the "Risk Factors" section The company has been
# working to mitigate the effects of Brexit, but the legal and operational challenges of international
# business operations, government controls, and regulatory approvals may still The company's products
# and product candidates face challenges from external factors, including reimbursement and pricing
# pressures from commercial and government payers outside the US, as well as Our products face
# increasing competition from biosimilars and generics, and we expect this trend to continue as
# biosimilar and generic competition accelerates due to patent The company is facing significant
# regulatory risks and challenges in obtaining and maintaining approval for its products and product
# candidates, including the potential for accelerated approval to lapse, changes The manufacturing
# facility's ability to operate and supply products is impacted by various factors, including the
# unreliability of the electric service in Puerto Rico, the risk The biotechnology company, Amgen,
# faces significant risks related to its commercial manufacturing activities, including production
# failures at its facilities in Puerto Rico and California, which The company's product sales were
# relatively flat for 2021, with volume growth offset by declines in net selling prices, and are
# expected to continue to decline The document reports financial data for a company, including sales,
# costs, and operating expenses, as well as its financial position and liquidity. The company's total
# The company has various financing arrangements to meet its liquidity requirements, including
# commercial paper, syndicated credit facilities, and access to debt and equity markets. As of The
# company is subject to temporary differences between its tax bases and reported amounts of assets and
# liabilities, resulting in deferred tax assets and liabilities. Deferred tax assets are

# %%
session.close()

# %%
torch.cuda.empty_cache()
